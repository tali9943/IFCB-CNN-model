# %% [markdown]
# # CNN for placton classification

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ## Image rotation adding colored padding

# %%
from collections import Counter

def get_background_color(img):
    """
    Determines the background color of the image by analyzing the border pixels.

    Parameters:
    - img (PIL.Image.Image): Opened and converted image in RGB.

    Returns:
    - background_color (tuple): Determined background color (R, G, B).
    """
    pixels = []
    width, height = img.size

    # Get pixels from the top and bottom borders
    for x in range(width):
        pixels.append(img.getpixel((x, 0)))           # Top border
        pixels.append(img.getpixel((x, height - 1)))  # Bottom border

    # Get pixels from the left and right borders
    for y in range(height):
        pixels.append(img.getpixel((0, y)))           # Left border
        pixels.append(img.getpixel((width - 1, y)))   # Right border

    # Count the colors and find the most common one
    color_counts = Counter(pixels)
    background_color = color_counts.most_common(1)[0][0]

    return background_color

# %%
import os
from PIL import Image, ImageFile, ImageOps
from collections import Counter
from tqdm import tqdm

# To handle truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

def get_resampling_methods():
    """
    Determines the available interpolation methods based on the Pillow version.

    Returns:
    - A list of interpolation methods in order of preference, excluding LANCZOS.
    """
    try:
        # Pillow 10.x and later
        from PIL import Image
        if hasattr(Image, 'Resampling'):
            return [Image.Resampling.BICUBIC, Image.Resampling.BILINEAR, Image.Resampling.NEAREST]
        else:
            return [Image.BICUBIC, Image.BILINEAR, Image.NEAREST]
    except AttributeError:
        # Pillow 9.x and earlier
        return [Image.BICUBIC, Image.BILINEAR, Image.NEAREST]



def augment_dataset_with_high_quality_rotations_colored(dataset_path, n, image_extensions=None, max_rotation_degree=360):
    """
    Augments images in each subfolder of the dataset by rotating them with smaller angles to ensure
    at least 'n' images per subfolder, using high-quality rotation to minimize artifacts.

    Parameters:
    - dataset_path (str): Path to the dataset directory containing subfolders with images.
    - n (int): Minimum number of images required per subfolder after augmentation.
    - image_extensions (set, optional): Set of image file extensions to consider.
                                         Defaults to common image formats.
    - max_rotation_degree (int, optional): Maximum degree for rotation (default is 360).
    """
    if image_extensions is None:
        # Define common image extensions
        image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif'}

    # Get the list of interpolation methods in order of preference
    resampling_methods = get_resampling_methods()

    # Iterate through each subfolder in the dataset path
    for subfolder in tqdm(os.listdir(dataset_path), desc="Subfolders"):
        subfolder_path = os.path.join(dataset_path, subfolder)

        # Ensure it is a directory
        if not os.path.isdir(subfolder_path):
            continue

        # List all image files in the subfolder
        images = [f for f in os.listdir(subfolder_path)
                  if os.path.isfile(os.path.join(subfolder_path, f)) and
                  os.path.splitext(f.lower())[1] in image_extensions]

        m = len(images)  # Current number of images

        print(f"\nProcessing folder: {subfolder} | Current images: {m}")

        if m == 0:
            print(f"Warning: No images found in folder '{subfolder}'. Skipping augmentation.")
            continue

        if m >= n:
            print(f"Folder '{subfolder}' already has {m} images. Skipping augmentation.")
            continue

        # Calculate the total number of additional images needed
        delta = n - m

        # Calculate the number of rotations per image
        # Distribute rotations as evenly as possible
        rotations_per_image = delta // m
        extra_rotations = delta % m  # Some images will have an additional rotation

        print(f"Each image will be rotated {rotations_per_image} times.")
        if extra_rotations > 0:
            print(f"{extra_rotations} images will be rotated an additional time.")

        for idx, image_name in enumerate(images):
            image_path = os.path.join(subfolder_path, image_name)
            try:
                with Image.open(image_path).convert('RGB') as img:
                    # Determine the background color
                    background_color = get_background_color(img)

                    # Determine the number of rotations for this image
                    num_rotations = rotations_per_image + (1 if idx < extra_rotations else 0)

                    if num_rotations == 0:
                        continue  # No rotation needed for this image

                    # Calculate the rotation step angle
                    # To ensure variety, divide max_rotation_degree by the number of rotations +1
                    step_angle = max_rotation_degree / (num_rotations + 1)

                    for rot in range(1, num_rotations + 1):
                        # Calculate the rotation angle
                        angle = (rot * step_angle) % max_rotation_degree

                        # Try rotating with available interpolation methods, using fillcolor
                        rotated_img = None
                        for method in resampling_methods:
                            try:
                                # Check if the rotation method supports 'fillcolor'
                                rotated_img = img.rotate(angle, resample=method, expand=True, fillcolor=background_color)
                                print(f"Rotated with method {method} and fillcolor.")
                                break  # If rotation succeeds, exit the loop
                            except TypeError:
                                # If 'fillcolor' is not supported, rotate without fillcolor and add the fill manually
                                rotated_img = img.rotate(angle, resample=method, expand=True)
                                # Create a new image with the background color
                                background = Image.new(rotated_img.mode, rotated_img.size, background_color)
                                # Paste the rotated image onto the new background image
                                if rotated_img.mode == 'RGBA':
                                    background.paste(rotated_img, mask=rotated_img.split()[3])  # Use the alpha channel as mask
                                else:
                                    background.paste(rotated_img)
                                rotated_img = background
                                print(f"Rotated with method {method} without fillcolor, added background manually.")
                                break  # Exit the loop after manually adding the fill
                            except Exception as e:
                                print(f"Unexpected error with method {method}: {e}")
                                continue  # Try the next method

                        if rotated_img is None:
                            print(f"Failed to rotate image '{image_name}' with angle {angle}. Skipping.")
                            continue

                        # Create a new name for the rotated image
                        base, ext = os.path.splitext(image_name)
                        new_image_name = f"{base}_rot{int(angle)}{ext}"
                        new_image_path = os.path.join(subfolder_path, new_image_name)

                        # Avoid overwriting existing images
                        counter = 1
                        while os.path.exists(new_image_path):
                            new_image_name = f"{base}_rot{int(angle)}_{counter}{ext}"
                            new_image_path = os.path.join(subfolder_path, new_image_name)
                            counter += 1
                            if counter > 100:
                                print(f"Too many duplicates for image '{image_name}'. Skipping this rotation.")
                                rotated_img = None
                                break

                        if rotated_img is None:
                            continue

                        # Save the rotated image with high quality
                        if ext.lower() in ['.jpg', '.jpeg']:
                            rotated_img.save(new_image_path, quality=95)
                        else:
                            rotated_img.save(new_image_path)

                        print(f"Saved rotated image: {new_image_name}")

            except Exception as e:
                print(f"Error processing image '{image_name}': {e}")

        # Optional: Verify the number of images after augmentation
        new_images = [f for f in os.listdir(subfolder_path)
                     if os.path.isfile(os.path.join(subfolder_path, f)) and
                     os.path.splitext(f.lower())[1] in image_extensions]
        new_m = len(new_images)
        print(f"After augmentation, folder '{subfolder}' has {new_m} images.\n")

# %%
import os
from PIL import Image, ImageFile, ImageOps
from collections import Counter
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
import traceback

# Per gestire immagini troncate
ImageFile.LOAD_TRUNCATED_IMAGES = True



def process_image(args):
    """
    Elabora una singola immagine: ridimensiona mantenendo l'aspect ratio e aggiunge padding dinamico.

    Parametri:
    - args (tuple): Tuple contenente (input_image_path, target_size).

    Ritorna:
    - None o messaggio di errore.
    """
    input_image_path, target_size = args
    try:
        with Image.open(input_image_path).convert('RGB') as img:
            # Determina il colore di sfondo
            background_color = get_background_color(img)

            # Determina il metodo di resampling
            try:
                resample_method = Image.Resampling.LANCZOS
            except AttributeError:
                # Per versioni più vecchie di Pillow
                resample_method = Image.ANTIALIAS

            # Calcola il rapporto per mantenere l'aspect ratio
            ratio = min(target_size[0] / img.width, target_size[1] / img.height)
            new_size = (int(img.width * ratio), int(img.height * ratio))

            # Ridimensiona l'immagine
            img_resized = img.resize(new_size, resample=resample_method)

            # Calcola il padding necessario
            delta_w = target_size[0] - new_size[0]
            delta_h = target_size[1] - new_size[1]
            padding = (
                delta_w // 2,             # Padding sinistro
                delta_h // 2,             # Padding superiore
                delta_w - (delta_w // 2), # Padding destro
                delta_h - (delta_h // 2)  # Padding inferiore
            )

            # Aggiungi il padding con il colore di sfondo
            img_padded = ImageOps.expand(img_resized, padding, fill=background_color)

            # Sovrascrivi l'immagine originale con quella preelaborata
            img_padded.save(input_image_path)

        return None  # Nessun errore

    except Exception as e:
        error_message = f"Error processing {input_image_path}: {e}"
        # Opzionale: stampa lo stack trace per debug
        traceback_str = traceback.format_exc()
        return f"{error_message}\n{traceback_str}"


def preprocess_dataset_with_dynamic_padding_colored(input_dir, target_size=(224, 224)):
    """
    Preprocessa un dataset di immagini ridimensionando ciascuna immagine mantenendo l'aspect ratio
    e aggiungendo padding con il colore di sfondo dell'immagine. Le immagini preelaborate sovrascrivono
    le immagini originali, mantenendo la struttura delle sottocartelle.

    Parametri:
    - input_dir (str): Percorso alla directory del dataset originale.
    - target_size (tuple): Dimensione desiderata per le immagini (larghezza, altezza).

    Ritorna:
    - None
    """
    # Raccogli tutti i percorsi delle immagini
    image_paths = []
    classes = [d for d in os.listdir(input_dir) if os.path.isdir(os.path.join(input_dir, d))]

    for class_name in classes:
        class_input_path = os.path.join(input_dir, class_name)
        # Filtra solo i file con estensioni comuni di immagini
        valid_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif')
        image_files = [
            os.path.join(class_input_path, f)
            for f in os.listdir(class_input_path)
            if os.path.isfile(os.path.join(class_input_path, f)) and f.lower().endswith(valid_extensions)
        ]
        image_paths.extend([(path, target_size) for path in image_files])

    print(f"Totale immagini da processare: {len(image_paths)}")

    # Determina il numero di processi da utilizzare
    num_processes = cpu_count() - 1 if cpu_count() > 1 else 1  # Lascia un CPU libero
    print(f"Utilizzo di {num_processes} processi per la preelaborazione delle immagini.")

    # Utilizza multiprocessing Pool per elaborare le immagini in parallelo
    with Pool(processes=num_processes) as pool:
        # Utilizza tqdm per mostrare la barra di avanzamento
        for result in tqdm(pool.imap_unordered(process_image, image_paths), total=len(image_paths), desc="Elaborazione Immagini"):
            if result is not None:
                print(result)  # Stampa eventuali errori

    print("Preelaborazione in loco con padding dinamico completata!")

# %%
dataset_directory = '/content/drive/MyDrive/CNN-CNR/Datasets/final-200'
minimum_images = 200

augment_dataset_with_high_quality_rotations_colored(dataset_directory, minimum_images)
# Out:
# Subfolders:   0%|          | 0/25 [00:00<?, ?it/s]
# Processing folder: Chaetoceros spp. | Current images: 200
# Folder 'Chaetoceros spp.' already has 200 images. Skipping augmentation.
#
# Processing folder: Leptocylindrus danicus | Current images: 51
# Each image will be rotated 2 times.
# 47 images will be rotated an additional time.
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00360_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00360_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00360_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01017_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01017_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01017_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00578_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00578_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00578_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00574_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00574_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00574_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00305_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00305_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00305_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00201_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00201_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00201_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00646_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00646_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00646_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00184_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00184_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00184_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00883_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00883_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00883_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00348_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00348_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00348_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_01331_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_01331_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_01331_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00656_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00656_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00656_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00381_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00381_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00381_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00419_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00419_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00419_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00060_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00060_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00060_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00796_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00796_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00796_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00015_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00015_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00015_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00083_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00083_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00083_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00273_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00273_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00273_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00050_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00050_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00050_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00117_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00117_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00117_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00905_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00905_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_081645_00905_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00078_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00078_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00078_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00163_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00163_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00163_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00917_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00917_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00917_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00580_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00580_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00580_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00379_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00379_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00379_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00364_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00364_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00364_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00039_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00039_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00039_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01023_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01023_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01023_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00779_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00779_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00779_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00387_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00387_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00387_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01216_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01216_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01216_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00650_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00650_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00650_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00903_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00903_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00903_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01332_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01332_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01332_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00154_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00154_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_00154_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00036_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00036_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00036_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01307_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01307_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_083957_01307_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00677_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00677_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00677_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00422_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00422_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00422_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00361_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00361_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_001_075331_00361_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00521_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00521_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00521_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01223_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01223_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_01223_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00633_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00633_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00633_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00129_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00129_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: Copia di IFCB1_2013_011_174553_00129_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00231_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00231_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00231_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00353_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00353_rot240.png
# Rotated with method 3 and fillcolor.
# Subfolders:   8%|▊         | 2/25 [00:02<00:34,  1.49s/it]
# Saved rotated image: D20240912T092716_IFCB182_00074_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00074_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00045_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00045_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00357_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00357_rot240.png
# After augmentation, folder 'Leptocylindrus danicus' has 200 images.
#
#
# Processing folder: Und. pennate diatoms >20 | Current images: 24
# Each image will be rotated 7 times.
# 8 images will be rotated an additional time.
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00175_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00443_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00126_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00702_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00412_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00762_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01505_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot40.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot80.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot160.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot200.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot280.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00521_rot320.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00441_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00422_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00138_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00071_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00034_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00182_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00262_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00906_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00874_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00340_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00993_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00248_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T092716_IFCB182_00057_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01478_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01011_rot315.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot45.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot90.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot135.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot225.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot270.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00085_rot315.png
# Subfolders:  12%|█▏        | 3/25 [00:06<00:51,  2.34s/it]
# After augmentation, folder 'Und. pennate diatoms >20' has 200 images.
#
#
# Processing folder: Gymnodinium spp. <20 | Current images: 104
# Each image will be rotated 0 times.
# 96 images will be rotated an additional time.
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210713T120326_IFCB114_00495_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_00430_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00551_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_01683_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T120255_IFCB114_04236_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_02165_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_02120_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T051824_IFCB114_02934_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01432_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_00373_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210713T120326_IFCB114_03964_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210525T115014_IFCB114_01668_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210511T120036_IFCB114_00257_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_02529_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T023238_IFCB114_00268_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T032000_IFCB114_05413_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T032000_IFCB114_04505_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01491_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T023238_IFCB114_02524_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210601T120001_IFCB114_00648_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_02202_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_01477_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_01622_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_04846_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T032000_IFCB114_01895_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_00357_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01225_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T023238_IFCB114_00725_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210615T114408_IFCB114_01305_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_02431_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00567_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_00185_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210525T115014_IFCB114_00836_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00345_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210615T114408_IFCB114_01270_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T051824_IFCB114_04025_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T120255_IFCB114_02641_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210615T114408_IFCB114_00801_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T034341_IFCB114_05765_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00787_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01423_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210921T115117_IFCB114_00655_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_02230_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_00371_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_02039_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210525T115014_IFCB114_00941_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_01417_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_02072_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T051824_IFCB114_03978_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T023238_IFCB114_02906_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00379_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_02154_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210427T121500_IFCB114_00832_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_01470_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03502_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00577_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_04106_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_04885_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210519T120718_IFCB114_00082_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00912_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03515_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210601T120001_IFCB114_00353_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_02946_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_01747_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_03073_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03924_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210806T185642_IFCB114_00956_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_03521_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03945_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00463_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_02115_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T051824_IFCB114_02257_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210803T120742_IFCB114_02105_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_04079_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210525T115014_IFCB114_00815_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03849_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T032000_IFCB114_03242_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_04963_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_03603_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_01240_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210803T120742_IFCB114_01290_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210316T115215_IFCB114_00198_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20230616T162502_IFCB182_00076_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_05640_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_02795_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210601T120001_IFCB114_00152_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00029_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_01784_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01984_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_01114_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210706T120205_IFCB114_02731_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210810T032000_IFCB114_01914_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210622T120526_IFCB114_03614_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210608T115904_IFCB114_00647_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210713T120326_IFCB114_07626_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20210615T114408_IFCB114_00616_rot180.png
# Subfolders:  16%|█▌        | 4/25 [00:08<00:46,  2.21s/it]
# After augmentation, folder 'Gymnodinium spp. <20' has 200 images.
#
#
# Processing folder: Chaetoceros tortissimius | Current images: 111
# Each image will be rotated 0 times.
# 89 images will be rotated an additional time.
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00357_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00341_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00140_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00173_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00034_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00085_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00102_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00124_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00250_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00895_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00862_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00205_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00377_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00404_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01008_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00288_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01023_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00090_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00347_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00352_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00234_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00008_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00062_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00564_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00449_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00447_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00693_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00880_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00471_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01098_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00842_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00687_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00228_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00262_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00227_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00366_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00494_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00312_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00289_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00502_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_00192_rot180.png
# Rotated with method 3 and fillcolor.
# ...
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01129_rot60.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01129_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01129_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01129_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20221018T081629_IFCB182_01129_rot300.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00031_rot60.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00031_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00031_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00031_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240628T081006_IFCB182_00031_rot300.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00013_rot60.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00013_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00013_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00013_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00013_rot300.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00323_rot60.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00323_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00323_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00323_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00323_rot300.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00272_rot60.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00272_rot120.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00272_rot180.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00272_rot240.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00272_rot300.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00488_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00488_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00488_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00488_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00426_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00426_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00426_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00426_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00296_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00296_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00296_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00296_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00234_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00234_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00234_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00234_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00377_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00377_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00377_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00377_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00906_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00906_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00906_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00906_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00545_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00545_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00545_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00545_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00926_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00926_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00926_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_00926_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01141_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01141_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01141_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01141_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01224_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01224_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01224_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01224_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01171_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01171_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01171_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01171_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01159_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01159_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01159_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01159_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01271_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01271_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01271_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01271_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01084_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01084_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01084_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01084_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01315_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01315_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01315_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240823T132208_IFCB182_01315_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00297_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00297_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00297_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00297_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00563_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00563_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00563_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T090443_IFCB182_00563_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00134_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00134_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00134_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00134_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_01996_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_01996_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_01996_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_01996_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00898_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00898_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00898_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_00898_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02196_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02196_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02196_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02196_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02015_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02015_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02015_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02015_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02283_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02283_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02283_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02283_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02532_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02532_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02532_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02532_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02822_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02822_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02822_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02822_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03297_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03297_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03297_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03297_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02939_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02939_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02939_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_02939_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03540_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03540_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03540_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_192358_03540_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00113_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00113_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00113_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00113_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01725_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01725_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01725_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01725_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00172_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00172_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00172_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_00172_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01745_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01745_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01745_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01745_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00330_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00330_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00330_rot216.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: D20240912T094948_IFCB182_00330_rot288.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01849_rot72.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01849_rot144.png
# Rotated with method 3 and fillcolor.
# Saved rotated image: IFCB1_2014_150_194713_01849_rot216.png
# Rotated with method 3 and fillcolor.
# Subfolders: 100%|██████████| 25/25 [01:53<00:00,  4.53s/it]
# Saved rotated image: IFCB1_2014_150_194713_01849_rot288.png
# After augmentation, folder 'Cylindrotheca closterium' has 200 images.

# %%
preprocess_dataset_with_dynamic_padding_colored(dataset_directory)
# Out:
# Totale immagini da processare: 5000
# Utilizzo di 1 processi per la preelaborazione delle immagini.
# Elaborazione Immagini: 100%|██████████| 5000/5000 [02:40<00:00, 31.18it/s]
# Preelaborazione in loco con padding dinamico completata!

# %% [markdown]
# ## Take the class the have at least n images

# %%
import os
import shutil



def create_filtered_dataset(input_dir, output_dir, min_count):
    """
    Create a new dataset containing only classes (subdirectories) that have at least a minimum number of elements (images).

    :param input_dir: The directory of the original dataset. It should contain subdirectories corresponding to classes.
    :param output_dir: The directory where the filtered dataset will be created.
    :param min_count: The minimum number of elements (images) that a class must contain to be included.
    """
    # Ensure the output directory exists, if not create it
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Iterate over each subdirectory in the input dataset
    for class_name in os.listdir(input_dir):
        class_path = os.path.join(input_dir, class_name)

        # Check if it's a directory (class folder)
        if os.path.isdir(class_path):
            # Get the list of elements in the class directory
            elements = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]

            # Check if the number of elements meets the minimum count requirement
            if len(elements) >= min_count:
                # Create the class directory in the output dataset
                target_class_path = os.path.join(output_dir, class_name)
                if not os.path.exists(target_class_path):
                    os.makedirs(target_class_path)

                # Copy all elements from the original class directory to the filtered dataset
                for element in elements:
                    src_path = os.path.join(class_path, element)
                    dst_path = os.path.join(target_class_path, element)
                    shutil.copy(src_path, dst_path)

    print(f"Filtered dataset created successfully at {output_dir}!")



input_dir ='/content/drive/MyDrive/CNN-CNR/backup/Dataset-plancton-cnr-original-final-version-AUGMENTED'

output_file = "/content/drive/MyDrive/CNN-CNR/Datasets/final-15"


#create_filtered_dataset(input_dir, output_file, 15)

# %% [markdown]
# ## Creation of a subset dataset

# %%
import os
import shutil
import random
from tqdm import tqdm

def create_subset_dataset(original_path, new_path, n, seed=None, extensions=None):
    """
    Creates a new dataset containing up to 'n' images per class from the original dataset.

    :param original_path: Path to the original dataset.
    :param new_path: Path where the new subset dataset will be saved.
    :param n: Number of images to select per class.
    :param seed: (Optional) Seed for reproducibility of random selection.
    :param extensions: (Optional) List of file extensions to consider as images (e.g., ['.jpg', '.png']).
    """
    # Set the seed for reproducibility if provided
    if seed is not None:
        random.seed(seed)

    # Define default image extensions if none are provided
    if extensions is None:
        extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']

    # Check if the original path exists
    if not os.path.exists(original_path):
        raise FileNotFoundError(f"The original path '{original_path}' does not exist.")

    # Create the new dataset directory if it doesn't exist
    os.makedirs(new_path, exist_ok=True)

    # List all classes (subdirectories) in the original dataset
    classes = [d for d in os.listdir(original_path) if os.path.isdir(os.path.join(original_path, d))]

    # Iterate over each class with a progress bar
    for class_name in tqdm(classes, desc="Processing classes"):
        original_class_path = os.path.join(original_path, class_name)

        # List all files in the class directory and filter by the specified extensions
        images = [
            img for img in os.listdir(original_class_path)
            if os.path.isfile(os.path.join(original_class_path, img)) and
               os.path.splitext(img)[1].lower() in extensions
        ]

        # Check if there are enough images; if not, use all available images
        if len(images) < n:
            print(f"Warning: Class '{class_name}' has only {len(images)} images. All will be copied.")
            selected_images = images
        else:
            selected_images = random.sample(images, n)

        # Create the class directory in the new dataset
        new_class_path = os.path.join(new_path, class_name)
        os.makedirs(new_class_path, exist_ok=True)

        # Copy the selected images to the new class directory
        for img in selected_images:
            src = os.path.join(original_class_path, img)
            dst = os.path.join(new_class_path, img)
            shutil.copy2(src, dst)

    print(f"New dataset created at '{new_path}' with up to {n} images per class.")


original_path = '/content/drive/MyDrive/CNN-CNR/Datasets/final-200-v2'
new_path = '/content/drive/MyDrive/CNN-CNR/Datasets/final-200'
n = 200
seed = 42

create_subset_dataset(original_path, new_path, n, seed=None, extensions=None)
# Out:
# Processing classes:   4%|▍         | 1/25 [00:10<04:11, 10.46s/it]
# Warning: Class 'Leptocylindrus danicus' has only 51 images. All will be copied.
# Processing classes:   8%|▊         | 2/25 [00:27<05:31, 14.42s/it]
# Warning: Class 'Und. pennate diatoms >20' has only 24 images. All will be copied.
# Processing classes:  12%|█▏        | 3/25 [00:34<03:59, 10.89s/it]
# Warning: Class 'Gymnodinium spp. <20' has only 104 images. All will be copied.
# Processing classes:  16%|█▌        | 4/25 [00:36<02:38,  7.54s/it]
# Warning: Class 'Chaetoceros tortissimius' has only 111 images. All will be copied.
# Processing classes:  20%|██        | 5/25 [00:39<01:56,  5.83s/it]
# Warning: Class 'Bacteriastrum jadranum' has only 22 images. All will be copied.
# Processing classes:  24%|██▍       | 6/25 [00:46<01:55,  6.08s/it]
# Warning: Class 'Thalassiosira spp. >10' has only 16 images. All will be copied.
# Processing classes:  32%|███▏      | 8/25 [00:56<01:35,  5.59s/it]
# Warning: Class 'Bacteriastrum furcatum' has only 15 images. All will be copied.
# Processing classes:  36%|███▌      | 9/25 [01:01<01:25,  5.36s/it]
# Warning: Class 'Syracosphaera pulcra' has only 28 images. All will be copied.
# Processing classes:  40%|████      | 10/25 [01:08<01:32,  6.16s/it]
# Warning: Class 'Chaetoceros socialis' has only 118 images. All will be copied.
# Processing classes:  44%|████▍     | 11/25 [01:12<01:13,  5.24s/it]
# Warning: Class 'Cerataulina pelagica' has only 32 images. All will be copied.
# Processing classes:  48%|████▊     | 12/25 [01:20<01:20,  6.19s/it]
# Warning: Class 'Guinardia striata' has only 42 images. All will be copied.
# Processing classes:  52%|█████▏    | 13/25 [01:31<01:32,  7.71s/it]
# Warning: Class 'Dactyliosolen fragilissimus' has only 46 images. All will be copied.
# Processing classes:  56%|█████▌    | 14/25 [01:43<01:39,  9.04s/it]
# Warning: Class 'Eucampia cornuta' has only 62 images. All will be copied.
# Processing classes:  60%|██████    | 15/25 [02:00<01:54, 11.48s/it]
# Warning: Class 'Chaetoceros diversus' has only 83 images. All will be copied.
# Processing classes:  64%|██████▍   | 16/25 [02:24<02:17, 15.26s/it]
# Warning: Class 'Leptocylindrus mediterraneus' has only 33 images. All will be copied.
# Processing classes:  68%|██████▊   | 17/25 [02:33<01:45, 13.25s/it]
# Warning: Class 'Asterionellopsis glacialis' has only 31 images. All will be copied.
# Processing classes:  72%|███████▏  | 18/25 [02:43<01:25, 12.16s/it]
# Warning: Class 'Chaetoceros diadema' has only 21 images. All will be copied.
# Processing classes:  76%|███████▌  | 19/25 [02:50<01:04, 10.75s/it]
# Warning: Class 'Guinardia flaccida' has only 45 images. All will be copied.
# Processing classes:  84%|████████▍ | 21/25 [03:08<00:38,  9.66s/it]
# Warning: Class 'Und. naked dinoflagellates <20' has only 71 images. All will be copied.
# Processing classes:  88%|████████▊ | 22/25 [03:27<00:37, 12.44s/it]
# Warning: Class 'Merismopedia spp.' has only 102 images. All will be copied.
# Processing classes:  92%|█████████▏| 23/25 [03:30<00:18,  9.44s/it]
# Warning: Class 'Thalassiosira pseudonana' has only 23 images. All will be copied.
# Processing classes:  96%|█████████▌| 24/25 [03:36<00:08,  8.56s/it]
# Warning: Class 'Cylindrotheca closterium' has only 39 images. All will be copied.
# Processing classes: 100%|██████████| 25/25 [03:46<00:00,  9.06s/it]
# New dataset created at '/content/drive/MyDrive/CNN-CNR/Datasets/final-200' with up to 200 images per class.

# %% [markdown]
# ## SPLIT DATASET

# %%
import os
import shutil

def split_dataset_train_test(data_dir, output_dir, train_ratio=0.8, test_ratio=0.2):
    for split in ['train', 'test']:
        split_dir = os.path.join(output_dir, split)
        if not os.path.exists(split_dir):
            os.makedirs(split_dir)

    for class_name in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_dir):
            continue

        for split in ['train', 'test']:
            split_class_dir = os.path.join(output_dir, split, class_name)
            if not os.path.exists(split_class_dir):
                os.makedirs(split_class_dir)

        images = os.listdir(class_dir)
        images = [img for img in images if os.path.isfile(os.path.join(class_dir, img))]

        total_images = len(images)
        train_size = int(train_ratio * total_images)

        train_images = images[:train_size]
        test_images = images[train_size:]

        for img in train_images:
            src = os.path.join(class_dir, img)
            dst = os.path.join(output_dir, 'train', class_name, img)
            shutil.copyfile(src, dst)

        for img in test_images:
            src = os.path.join(class_dir, img)
            dst = os.path.join(output_dir, 'test', class_name, img)
            shutil.copyfile(src, dst)

    print(f"Dataset divided into training and test sets. Saved in {output_dir}")


data_dir ='/content/drive/MyDrive/CNN-CNR/Datasets/final-200'
output_dir = '/content/drive/MyDrive/CNN-CNR/Datasets/final-200-train-test'

split_dataset_train_test(data_dir, output_dir)
# Out:
# Dataset divided into training and test sets. Saved in /content/drive/MyDrive/CNN-CNR/Datasets/final-200-train-test

# %% [markdown]
# # Statistics

# %%
import os
import plotly.graph_objects as go
from torchvision import datasets

def plot_classes(dir):
    dataset = datasets.ImageFolder(dir)

    class_names = dataset.classes
    class_to_idx = dataset.class_to_idx

    class_counts = {class_name: 0 for class_name in class_names}

    for _, label in dataset.samples:
        class_name = class_names[label]
        class_counts[class_name] += 1

    total_images = sum(class_counts.values())
    total_classes = len(class_names)

    print(f"Number of images: {total_images}")
    print(f"Number of classes: {total_classes}")

    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=list(class_counts.keys()),
        y=list(class_counts.values()),
        marker_color='skyblue',
        hovertext=list(class_counts.keys()),
        hoverinfo="text+y"
    ))


    fig.update_layout(
        title='Number of Images per Class in Set',
        xaxis_title='Class Names',
        yaxis_title='Number of Images',
        xaxis_tickangle=-45,
        height=600,
        margin=dict(l=50, r=50, t=80, b=150),
    )

    fig.show()

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/Datasets/ORIGINAL/original')
# Out:
# Number of images: 5854
# Number of classes: 70
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9017592-3181-49b4-8e49-2b7def92472f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9017592-3181-49b4-8e49-2b7def92472f")) {                    Plotly.newPlot(                        "e9017592-3181-49b4-8e49-2b7def92472f",                        [{"hoverinfo":"text+y","hovertext":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflagellates \u003e20","Und. nanoflagellates","Und. pennate diatoms \u003c20","Und. pennate diatoms \u003e20","Und. thecate dinoflagellates \u003c20","Und. thecate dinoflagellates \u003e20","unclassified"],"marker":{"color":"skyblue"},"x":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflag ...

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/backup/final-15-backup')
# Out:
# Number of images: 2216
# Number of classes: 25
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4dce3e85-b4c2-4a33-a86d-c27e1f47e105" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dce3e85-b4c2-4a33-a86d-c27e1f47e105")) {                    Plotly.newPlot(                        "4dce3e85-b4c2-4a33-a86d-c27e1f47e105",                        [{"hoverinfo":"text+y","hovertext":["Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum jadranum","Cerataulina pelagica","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Cylindrotheca closterium","Dactyliosolen fragilissimus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Pleurosigma spp.","Syracosphaera pulcra","Thalassiosira pseudonana","Thalassiosira spp. \u003e10","Und. naked dinoflagellates \u003c20","Und. nanoflagellates","Und. pennate diatoms \u003e20"],"marker":{"color":"skyblue"},"x":["Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum jadranum","Cerataulina pelagica","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Cylindrotheca closterium","Dactyliosolen fragilissimus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Pleurosigma spp.","Syracosphaera pulcra","Thalassiosira pseudonana","Thalassiosira spp. \u003e10","Und. naked dinoflagellates \u003c20","Und. nanoflagellates","Und. pennate diatoms \u003e20"],"y":[31,15,22,32,21,83,118,529,111,39,46,62,45,42,104,51,33,102,216,28,23,16,71,352,24],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/Datasets/ORIGINAL/original-augmented')
# Out:
# Number of images: 6293
# Number of classes: 70
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2264efca-fd71-4838-bc04-bd1579ef38d8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2264efca-fd71-4838-bc04-bd1579ef38d8")) {                    Plotly.newPlot(                        "2264efca-fd71-4838-bc04-bd1579ef38d8",                        [{"hoverinfo":"text+y","hovertext":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflagellates \u003e20","Und. nanoflagellates","Und. pennate diatoms \u003c20","Und. pennate diatoms \u003e20","Und. thecate dinoflagellates \u003c20","Und. thecate dinoflagellates \u003e20","unclassified"],"marker":{"color":"skyblue"},"x":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflag ...

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/Datasets/final-200-train-test')
# Out:
# Number of images: 5000
# Number of classes: 2
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd5ae640-f7c1-454b-8770-a56066f030a5" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd5ae640-f7c1-454b-8770-a56066f030a5")) {                    Plotly.newPlot(                        "cd5ae640-f7c1-454b-8770-a56066f030a5",                        [{"hoverinfo":"text+y","hovertext":["test","train"],"marker":{"color":"skyblue"},"x":["test","train"],"y":[1000,4000],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marke ...

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/Datasets/final-150-train-test-v2/train')
# Out:
# Number of images: 3000
# Number of classes: 25
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ef3032a-0025-4700-b892-1024ff991e04" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ef3032a-0025-4700-b892-1024ff991e04")) {                    Plotly.newPlot(                        "0ef3032a-0025-4700-b892-1024ff991e04",                        [{"hoverinfo":"text+y","hovertext":["Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum jadranum","Cerataulina pelagica","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Cylindrotheca closterium","Dactyliosolen fragilissimus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Pleurosigma spp.","Syracosphaera pulcra","Thalassiosira pseudonana","Thalassiosira spp. \u003e10","Und. naked dinoflagellates \u003c20","Und. nanoflagellates","Und. pennate diatoms \u003e20"],"marker":{"color":"skyblue"},"x":["Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum jadranum","Cerataulina pelagica","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Cylindrotheca closterium","Dactyliosolen fragilissimus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Pleurosigma spp.","Syracosphaera pulcra","Thalassiosira pseudonana","Thalassiosira spp. \u003e10","Und. naked dinoflagellates \u003c20","Und. nanoflagellates","Und. pennate diatoms \u003e20"],"y":[120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120,120],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"# ...

# %%
plot_classes('/content/drive/MyDrive/CNN-CNR/Datasets/final-200-train-test/train')
# Out:
# Number of images: 11200
# Number of classes: 70
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de99e817-8ddd-484c-83f8-00d16804de31" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de99e817-8ddd-484c-83f8-00d16804de31")) {                    Plotly.newPlot(                        "de99e817-8ddd-484c-83f8-00d16804de31",                        [{"hoverinfo":"text+y","hovertext":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflagellates \u003e20","Und. nanoflagellates","Und. pennate diatoms \u003c20","Und. pennate diatoms \u003e20","Und. thecate dinoflagellates \u003c20","Und. thecate dinoflagellates \u003e20","unclassified"],"marker":{"color":"skyblue"},"x":["Akashiwo sanguinea","Asterionellopsis glacialis","Bacteriastrum furcatum","Bacteriastrum hyalinum","Bacteriastrum jadranum","Bacteriastrum spp.","Calciosolenia murrayi","Cerataulina pelagica","Chaetoceros affinis","Chaetoceros anastomosans","Chaetoceros brevis","Chaetoceros costatus","Chaetoceros decipiens","Chaetoceros diadema","Chaetoceros diversus","Chaetoceros radicans","Chaetoceros socialis","Chaetoceros spp.","Chaetoceros tortissimius","Chrysochromulina parkeae","Cyclotella spp. \u003c10","Cyclotella spp. \u003e10","Cylindrotheca closterium","Dactyliosolen fragilissimus","Dinophysis sacculus","Eucampia cornuta","Guinardia flaccida","Guinardia striata","Gymnodinium spp. \u003c20","Hemiaulus hauckii","Hemiaulus sinensis","Hermesinum adriaticum","Leptocylindrus danicus","Leptocylindrus mediterraneus","Merismopedia spp.","Navicula spp. \u003c20","Navicula spp. \u003e20","Nitzschia spp. \u003c20","Nitzschia spp. \u003e20","Ollicola vangorii","Ophiaster hydroideus","Oxytoxum sceptrum","Pleurosigma spp.","Prorocentrum compressum","Prorocentrum gracile","Prorocentrum minimum","Protoperidinium bipes","Pseudo-Nitzschia delicatissima complex","Pseudo-nitzschia spp.","Rhabdosphaera clavigera","Scrippsiella trochoidea","Syracosphaera pulcra","Thalassionema nitzschioides","Thalassiosira pseudonana","Thalassiosira spp. \u003c10","Thalassiosira spp. \u003e10","Und. Coccolithophores","Und. Cryptophyceans","Und. Euglenophyceans","Und. centric diatoms \u003c10","Und. centric diatoms \u003e10","Und. ciliophora ","Und. naked dinoflagellates \u003c20","Und. naked dinoflag ...

# %% [markdown]
# ## Class Distribution

# %%
import os

def get_class_distribution(dataset_path, reverse=False, output_file=None):
    class_distribution = []

    for class_name in os.listdir(dataset_path):
        class_path = os.path.join(dataset_path, class_name)

        if os.path.isdir(class_path):
            num_elements = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
            class_distribution.append((class_name, num_elements))

    sorted_distribution = sorted(class_distribution, key=lambda x: x[1], reverse=reverse)

    # Save to file if output_file path is provided
    if output_file:
        with open(output_file, 'w') as f:
            for class_name, num_elements in sorted_distribution:
                f.write(f"{class_name}: {num_elements}\n")

    return sorted_distribution

dataset_path ='/content/drive/MyDrive/CNN-CNR/backup/min-15-copied'
output_file = "/content/drive/MyDrive/CNN-CNR/Utili/distribution-original-dataset-min-15.txt"
#distribution = get_class_distribution(dataset_path, reverse=True, output_file=output_file)

for class_name, count in distribution:
    print(f"Class: {class_name}, Number of images: {count}")
